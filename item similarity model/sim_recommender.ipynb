# %%
import pandas as pd
import datetime
import pytz
from operator import itemgetter
import fasttext
import csv
from difflib import SequenceMatcher

base_path = "../"

# %%
# pd.read_csv('W_SC_11_6.csv').sort_values(['score'], ascending=False)

# %%
orig_items = pd.read_pickle(f"{base_path}data/items_wd_v2.pkl")
test = pd.read_csv(f"{base_path}data/evaluation.csv").join(orig_items.set_index('itemID'), on='itemID').rename(columns={"main topic": "main_topic"})

# loading train items without any duplicates
items = pd.read_pickle(f"{base_path}data/items_v2.pkl").set_index('itemID').rename(columns={"main topic": "main_topic"})

print(f'Item columns {items.columns.tolist()}')
# Out:
# Item columns ['title', 'author', 'publisher', 'main_topic', 'subtopics']

# %% [markdown]
# # Detect language and score

# %%
model = fasttext.load_model(f"{base_path}fast_text_models/lid.176.bin")

def langdetect_score(title):
        title = title.replace('\n','')
        score = model.predict(title)[1][0]
        
        return score

def langdetect_lang(title):
        title = title.replace('\n','')
        language = str(model.predict(title)[0])

        return language

def trim(language):
    language = language.replace(language[:11], '')
    language = language[:-3]
    
    return language
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
orig_items['language'] = orig_items['title'].apply(langdetect_lang).apply(trim)
orig_items['language_score'] = orig_items['title'].apply(langdetect_score)

items['language'] = items['title'].apply(langdetect_lang).apply(trim)
items['language_score'] = items['title'].apply(langdetect_score)

test['language'] = test['title'].apply(langdetect_lang).apply(trim)
test['language_score'] = test['title'].apply(langdetect_score)

# %% [markdown]
# # Generate recommendations

# %%
def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

def title_handle(title1, title2):
    sim_title = similar(title1, title2)
    if(sim_title == 1):
        return 0
    else:
        return sim_title

def author_handle(author1, author2):
    sim_author = similar(author1, author2)
    if(sim_author < 0.8 or author1 == "Unknown" or author2 == "Unknown"):
        return 0
    else:
        return sim_author

def lang_handle(lang1, lang2, score1):
    if(similar(lang1, lang2) == 1):
        return score1
    else:
        return 0


def measure_similarity(book1, book2, scorings):
    sim_title = title_handle(book1.title,book2.title)
    sim_author = author_handle(book1.author, book2.author)
    sim_lang = lang_handle(book1.language, book2.language, book1.language_score)
    sim_main_topic = similar(book1.main_topic, book2.main_topic)
    sim_pub = similar(book1.publisher, book2.publisher)

    
    score = (
        (sim_author * scorings['sim_author']) + 
            (sim_main_topic * scorings['sim_main_topic']) + 
            (sim_title * scorings['sim_title']) + 
            (sim_lang * scorings['sim_lang']) +
            (sim_pub * scorings['sim_publisher'])
    )
#     score = sim_author * 0.2 + sim_main_topic * 0.3 + sim_title * 0.3 + sim_lang * 0.2
    
    return score


def get_top_n_recommendation(test_case, items, n, scorings):
    recommendations = []
    for index, item in items.iterrows():
        score = measure_similarity(item, test_case, scorings)
        if(score < 1.0):
            recommendations.append(
                {
                    'test_id': test_case.itemID,
                    'rec_id': index,
                    'score': round(score, 4)
                }
            )
            
    
    top_n = sorted(recommendations, key=itemgetter('score'), reverse=True)[:n]

    return top_n


def save_recommendations(result_df, prefix=None):
    # Saving recommendations
    if prefix is None:
        berlin_now = datetime.datetime.now(pytz.timezone('Europe/Berlin'))
        date_time = berlin_now.strftime("%d_%m_%Y_%H_%M_%S")
        prefix = f'{base_path}result/{date_time}'

    result_file_name_1 = f'{prefix}_recommendation_ids.csv'
    result_file_name_2 = f'{prefix}_recommendations.csv'
    
    result_df.to_csv(result_file_name_1, index=False)
    
    result_df_with_details = result_df.join(
        orig_items.set_index('itemID'),
        on='test_id',
        rsuffix='_test'
    ).join(
        orig_items.set_index('itemID'),
        on='rec_id',
        rsuffix='_rec'
    ).sort_values(by=['test_id', 'score'], ascending=[True, False])
    
    result_df_with_details.to_csv(result_file_name_2, index=False)


    print(f'Recommendations generated successfully. Files: \n\t{result_file_name_1}\n\t{result_file_name_2}')
    
    return result_df_with_details


def generate_recommendations(test_cases, n=30, scorings={
    'sim_title': 0.44,
    'sim_author': 0.18,
    'sim_lang': 0.08,
    'sim_publisher': 0.28,
    'sim_main_topic': 0.003,
    
}):
    result = { 
        'test_id': [],
        'rec_id': [],
        'score': []
    }
    
    counter = 0
    for index, test_case in test_cases.iterrows():
        counter = counter + 1
        print(f"({counter}) Working on the test item: id = {test_case['itemID']}, title = {test_case['title']}")
        recommendations = get_top_n_recommendation(test_case, items, n, scorings)

        for recommendation in recommendations:
            result['test_id'].append(recommendation['test_id'])
            result['rec_id'].append(recommendation['rec_id'])
            result['score'].append(recommendation['score'])


    result_df = pd.DataFrame(result).sort_values(by=['test_id', 'score'], ascending=[True, False])
    
    print(f'\n{n} recommendations generated for each of the {len(test_cases)} items\n')
    
    return result_df

# %%
result_df = generate_recommendations(test_cases=test.sample(2), n=5)
# result_df = generate_recommendations(test_cases=test.head(5), n=5)

result_df_with_details = save_recommendations(result_df, prefix=f'{base_path}result/test')

print(result_df.test_id.nunique(), len(result_df))
print(result_df_with_details.test_id.nunique(), len(result_df_with_details))
result_df_with_details
# Out:
# (1) Working on the test item: id = 55501, title = The Royal Ranger (Ranger's Apprentice Book 12)
# (2) Working on the test item: id = 61339, title = Ein Pferd namens Milchmann
#
# 5 recommendations generated for each of the 2 items
#
# Recommendations generated successfully. Files:
# 	../result/test_recommendation_ids.csv
# 	../result/test_recommendations.csv
# 2 10
# 2 10
#    test_id  rec_id   score                                           title  \
# 0    55501   67879  0.8588  The Royal Ranger (Ranger's Apprentice Book 12)
# 1    55501   22014  0.8535  The Royal Ranger (Ranger's Apprentice Book 12)
# 2    55501   28841  0.8425  The Royal Ranger (Ranger's Apprentice Book 12)
# 3    55501    6722  0.8398  The Royal Ranger (Ranger's Apprentice Book 12)
# 4    55501   73054  0.8388  The Royal Ranger (Ranger's Apprentice Book 12)
# 5    61339   53854  0.5760                      Ein Pferd namens Milchmann
# 6    61339   72375  0.5678                      Ein Pferd namens Milchmann
# 7    61339    8863  0.5485                      Ein Pferd namens Milchmann
# 8    61339   35421  0.5452                      Ein Pferd namens Milchmann
# 9    61339   51671  0.5436                      Ein Pferd namens Milchmann
#
#                    author                           publisher main_topic  \
# 0  John (Author) Flanagan  Penguin Random House Children's UK        YFC
# 1  John (Author) Flanagan  Penguin Random House Children's UK        YFC
# 2  John (Author) Flanagan  Penguin Random House Children's UK        YFC
# 3  John (Author) Flanagan  Penguin Random House Children's UK        YFC
# 4  John (Author) Flanagan  Penguin Random House Children's UK        YFC
# 5         Hilke Rosenboom                 Carlsen Verlag GmbH        YFP
# 6         Hilke Rosenboom                 Carlsen Verlag GmbH        YFP
# 7         Hilke Rosenboom                 Carlsen Verlag GmbH        YFP
# 8         Hilke Rosenboom                 Carlsen Verlag GmbH        YFP
# 9         Hilke Rosenboom                 Carlsen Verlag GmbH        YFP
#
#        subtopics language  language_score  \
# 0      [5AK,YFH]       en        0.530064
# 1      [5AK,YFH]       en        0.530064
# 2      [5AK,YFH]       en        0.530064
# 3      [5AK,YFH]       en        0.530064
# 4      [5AK,YFH]       en        0.530064
# 5  [5AJ,YFP,YFQ]       de        0.843264
# 6  [5AJ,YFP,YFQ]       de        0.843264
# 7  [5AJ,YFP,YFQ]       de        0.843264
# 8  [5AJ,YFP,YFQ]       de        0.843264
# 9  [5AJ,YFP,YFQ]       de        0.843264
#
#                                            title_rec              author_rec  \
# 0    The Burning Bridge (Ranger's Apprentice Book 2)  John (Author) Flanagan
# 1     The Icebound Land (Ranger's Apprentice Book 3)  John (Author) Flanagan
# 2       Oakleaf Bearers (Ranger's Apprentice Book 4)  John (Author) Flanagan
# 3         Erak's Ransom (Ranger's Apprentice Book 7)  John (Author) Flanagan
# 4  The Siege of Macindaw (Ranger's Apprentice Boo...  John (Author) Flanagan
# 5                        Ein Meer aus Tinte und Gold              Traci Chee
# 6                          Elefanten sieht man nicht           Susan Kreller
# 7                              Der mechanische Prinz      Andreas Steinhöfel
# 8                             Sophie auf den Dächern       Katherine Rundell
# 9                              Hundert Stunden Nacht              Anna Woltz
#
#                         publisher_rec main_topic_rec  \
# 0  Penguin Random House Children's UK            YFH
# 1  Penguin Random House Children's UK            YFH
# 2  Penguin Random House Children's UK            YFH
# 3  Penguin Random House Children's UK            YFC
# 4  Penguin Random House Children's UK            YFC
# 5                 Carlsen Verlag GmbH           YFZV
# 6                 Carlsen Verlag GmbH          JBFK3
# 7                 Carlsen Verlag GmbH            YFB
# 8                 Carlsen Verlag GmbH            YFH
# 9                 Carlsen Verlag GmbH            YFB
#
#                                        subtopics_rec language_rec  \
# 0                                              [5AK]           en
# 1                                              [5AK]           en
# 2                                              [5AK]           en
# 3                                              [5AK]           en
# 4                                                 []           en
# 5  [5AQ,5LF,FDK,FJ,FM,WFU,YFB,YFC,YFH,YFZV,YXE,YX...           de
# 6               [5AQ,JBFK,JBFK3,YFB,YFN,YXE,YXF,YXQ]           de
# 7                             [5AN,5HPD,YFB,YFC,YFH]           de
# 8                                          [5AM,YFN]           de
# 9                                  [5AQ,YFB,YFM,YFN]           de
#
#    language_score_rec
# 0            0.702210
# 1            0.589497
# 2            0.723180
# 3            0.584537
# 4            0.801659
# 5            0.980680
# 6            0.999598
# 7            0.991266
# 8            0.998460
# 9            0.929339

# %%
sanity_df = pd.read_csv(f"{base_path}result/test_recommendations.csv")
sanity_df
# Out:
#    test_id  rec_id   score                                  title  \
# 0    56300   53497  0.7111  Die Maus - Meine Kindergarten-Freunde
# 1    56300   15084  0.6831  Die Maus - Meine Kindergarten-Freunde
# 2    56300   29525  0.6725  Die Maus - Meine Kindergarten-Freunde
# 3    56300   31293  0.6696  Die Maus - Meine Kindergarten-Freunde
# 4    56300   40250  0.6665  Die Maus - Meine Kindergarten-Freunde
# 5    77134    7989  0.6476                Roxie and the Hooligans
# 6    77134   68886  0.6262                Roxie and the Hooligans
# 7    77134    8101  0.6157                Roxie and the Hooligans
# 8    77134   33814  0.6023                Roxie and the Hooligans
# 9    77134   70192  0.6002                Roxie and the Hooligans
#
#                     author         publisher main_topic       subtopics  \
# 0                  Unknown  Ars Edition GmbH          Y  [5A,5AC,YB,YF]
# 1                  Unknown  Ars Edition GmbH          Y  [5A,5AC,YB,YF]
# 2                  Unknown  Ars Edition GmbH          Y  [5A,5AC,YB,YF]
# 3                  Unknown  Ars Edition GmbH          Y  [5A,5AC,YB,YF]
# 4                  Unknown  Ars Edition GmbH          Y  [5A,5AC,YB,YF]
# 5  Phyllis Reynolds Naylor           ALADDIN        YFC       [YFQ,YXQ]
# 6  Phyllis Reynolds Naylor           ALADDIN        YFC       [YFQ,YXQ]
# 7  Phyllis Reynolds Naylor           ALADDIN        YFC       [YFQ,YXQ]
# 8  Phyllis Reynolds Naylor           ALADDIN        YFC       [YFQ,YXQ]
# 9  Phyllis Reynolds Naylor           ALADDIN        YFC       [YFQ,YXQ]
#
#   language  language_score                                   title_rec  \
# 0       de        0.900756                  Meine Kindergarten-Freunde
# 1       de        0.900756                   Meine Kindergartenfreunde
# 2       de        0.900756        Meine Kindergarten-Freunde (Fußball)
# 3       de        0.900756         Meine Kindergarten-Freunde (Pferde)
# 4       de        0.900756          Meine Kindergarten-Freunde (Pirat)
# 5       en        0.677107                      Eloise and the Snowman
# 6       en        0.677107                           The Witch Herself
# 7       en        0.677107  Roxie and the Hooligans at Buzzard's Roost
# 8       en        0.677107                 The Thief and the Beanstalk
# 9       en        0.677107          Pongwiffy and the Goblins' Revenge
#
#                     author_rec     publisher_rec main_topic_rec  \
# 0                      Unknown  Ars Edition GmbH            YBG
# 1                      Janosch  Ars Edition GmbH              Y
# 2                      Unknown  Ars Edition GmbH            YBG
# 3                      Unknown  Ars Edition GmbH            YBG
# 4                      Unknown  Ars Edition GmbH             YB
# 5  Kay Thompson, Hilary Knight           ALADDIN            YFQ
# 6      Phyllis Reynolds Naylor           ALADDIN           YFCF
# 7      Phyllis Reynolds Naylor    ATHENEUM BOOKS           YFCF
# 8               P. W. Catanese           ALADDIN            YFH
# 9                 Kaye Umansky           ALADDIN            YFQ
#
#                     subtopics_rec language_rec  language_score_rec
# 0          [5AC,YBL,YXHB,YZG,YZS]           de            0.830578
# 1                     [5AC,YB,YF]           de            0.743462
# 2      [5AC,YBG,YBL,YXHB,YZG,YZS]           de            0.969145
# 3  [5AC,5JA,YBG,YBL,YXHB,YZG,YZS]           de            0.879472
# 4            [5AC,5AD,YBG,YBL,YF]           de            0.778105
# 5                              []           en            0.903630
# 6                           [YFD]           en            0.670286
# 7                           [YFQ]           en            0.855458
# 8                           [YFJ]           en            0.924328
# 9                           [YFH]           en            0.889788

# %%
sanity_df.columns
# Out:
# Index(['test_id', 'rec_id', 'score', 'title', 'author', 'publisher',
#        'main_topic', 'subtopics', 'language', 'language_score', 'title_rec',
#        'author_rec', 'publisher_rec', 'main_topic_rec', 'subtopics_rec',
#        'language_rec', 'language_score_rec'],
#       dtype='object')

# %%
sanity_df[['test_id', 'rec_id']].rename(
    columns={"test_id": "test_itemID", "rec_id": "rec_itemID"}
).to_csv('item_similarity_recom.csv', index=False)

pd.read_csv(f"item_similarity_recom.csv")
# Out:
#       test_itemID  rec_itemID
# 0              12       65244
# 1              12       72230
# 2              12       28265
# 3              12       75432
# 4              12       32703
# ...           ...         ...
# 4995        79016       77768
# 4996        79016       53240
# 4997        79016       22802
# 4998        79016       46681
# 4999        79016        6624
#
# [5000 rows x 2 columns]

# %%
pd.read_csv('test_recommendations.csv').tail(15)
# Out:
#        test_id  rec_id   score               title                 author  \
# 14985    79016   77768  0.8023  Counting Dinosaurs  Speedy Publishing Llc
# 14986    79016   53240  0.7738  Counting Dinosaurs  Speedy Publishing Llc
# 14987    79016   22802  0.7718  Counting Dinosaurs  Speedy Publishing Llc
# 14988    79016   46681  0.7611  Counting Dinosaurs  Speedy Publishing Llc
# 14989    79016    6624  0.7469  Counting Dinosaurs  Speedy Publishing Llc
# 14990    79016   16151  0.7347  Counting Dinosaurs  Speedy Publishing Llc
# 14991    79016   48308  0.7270  Counting Dinosaurs  Speedy Publishing Llc
# 14992    79016    1827  0.7156  Counting Dinosaurs  Speedy Publishing Llc
# 14993    79016   64452  0.7102  Counting Dinosaurs  Speedy Publishing Llc
# 14994    79016   56257  0.7037  Counting Dinosaurs  Speedy Publishing Llc
# 14995    79016   26847  0.6913  Counting Dinosaurs  Speedy Publishing Llc
# 14996    79016   61049  0.6908  Counting Dinosaurs  Speedy Publishing Llc
# 14997    79016   13524  0.6892  Counting Dinosaurs  Speedy Publishing Llc
# 14998    79016   55652  0.6880  Counting Dinosaurs  Speedy Publishing Llc
# 14999    79016   12839  0.6867  Counting Dinosaurs  Speedy Publishing Llc
#
#                    publisher main_topic subtopics language  language_score  \
# 14985  Speedy Publishing LLC       YBLC        []       en        0.748285
# 14986  Speedy Publishing LLC       YBLC        []       en        0.748285
# 14987  Speedy Publishing LLC       YBLC        []       en        0.748285
# 14988  Speedy Publishing LLC       YBLC        []       en        0.748285
# 14989  Speedy Publishing LLC       YBLC        []       en        0.748285
# 14990  Speedy Publishing LLC       YBLC        []       en        0.748285
# 14991  Speedy Publishing LLC       YBLC        []       en        0.748285
# 14992  Speedy Publishing LLC       YBLC        []       en        0.748285
# 14993  Speedy Publishing LLC       YBLC        []       en        0.748285
# 14994  Speedy Publishing LLC       YBLC        []       en        0.748285
# 14995  Speedy Publishing LLC       YBLC        []       en        0.748285
# 14996  Speedy Publishing LLC       YBLC        []       en        0.748285
# 14997  Speedy Publishing LLC       YBLC        []       en        0.748285
# 14998  Speedy Publishing LLC       YBLC        []       en        0.748285
# 14999  Speedy Publishing LLC       YBLC        []       en        0.748285
#
#                                      title_rec             author_rec  \
# 14985                     Counting Colors Book  Speedy Publishing Llc
# 14986                      Counting And Colors  Speedy Publishing Llc
# 14987               Counting Book For Toddlers  Speedy Publishing Llc
# 14988               Counting Book For Big Kids  Speedy Publishing Llc
# 14989                  Counting Bears and Cubs  Speedy Publishing Llc
# 14990              Counting Apples and Oranges  Speedy Publishing Llc
# 14991             Counting Activities For Kids  Speedy Publishing Llc
# 14992                All about Me (Girl Diary)  Speedy Publishing Llc
# 14993               Counting Book For Big Kids  Speedy Publishing Llc
# 14994  Underdogs Coloring Book (Dogs and Pups)  Speedy Publishing Llc
# 14995            Counting Animals With Friends  Speedy Publishing Llc
# 14996             Giant Coloring Book for Kids  Speedy Publishing Llc
# 14997          Giant Drawing and Coloring Book  Speedy Publishing Llc
# 14998                       Baby Coloring Book  Speedy Publishing Llc
# 14999         Princess Coloring Book for Girls  Speedy Publishing Llc
#
#                  publisher_rec main_topic_rec subtopics_rec language_rec  \
# 14985    Speedy Publishing LLC           YBLC            []           en
# 14986  Speedy Publishing Books           YBLC            []           en
# 14987    Speedy Publishing LLC           YBLC            []           en
# 14988    Speedy Publishing LLC           YBLC            []           en
# 14989  Speedy Publishing Books           YBLC            []           en
# 14990  Speedy Publishing Books           YBLC            []           en
# 14991  Speedy Publishing Books           YBLC            []           en
# 14992    Speedy Publishing LLC            YBL            []           en
# 14993  Speedy Publishing Books           YBLC            []           en
# 14994    Speedy Publishing LLC            YBL            []           en
# 14995  Speedy Publishing Books           YBLC            []           en
# 14996    Speedy Publishing LLC            YBL            []           en
# 14997    Speedy Publishing LLC            YBL            []           en
# 14998    Speedy Publishing LLC            YBL            []           en
# 14999    Speedy Publishing LLC            YBL            []           en
#
#        language_score_rec
# 14985            0.767845
# 14986            0.656508
# 14987            0.859498
# 14988            0.726456
# 14989            0.965962
# 14990            0.855112
# 14991            0.827514
# 14992            0.859941
# 14993            0.726456
# 14994            0.890895
# 14995            0.681490
# 14996            0.700221
# 14997            0.812456
# 14998            0.679317
# 14999            0.821363

# %% [markdown]
# # Evaluate quality

# %%
def evaluate_scoring(cond, scorings, n=5):
    print(scorings, sum(scorings.values()))
    test_result_df = generate_recommendations(test_cases=test[cond_test], n=n, scorings=scorings)
    test_result_df_with_details = save_recommendations(test_result_df, prefix=f'{base_path}result/dummy')
    
    return test_result_df_with_details

# %% [markdown]
# ## ItemID = 14015

# %% [markdown]
# ### Current wieghts

# %%
# Current evaluation scoring weights
cond_test = test.itemID == 14015
scorings={
    'sim_author': 0.2,
    'sim_title': 0.3,
    'sim_main_topic': 0.3,
    'sim_lang': 0.2,
}
evaluate_scoring(cond_test, scorings)

# %%
evaluate_scoring(cond_test, scorings, n=20)

# %% [markdown]
# ### Alternative scorings

# %%
cond_test = test.itemID == 14015
scorings={
    'sim_author': 0.20,
    'sim_title': 0.60,
    'sim_lang': 0.15,
    'sim_main_topic': 0.05,
}
# We should consider publishers, there are more comics from STONE ARCH BOOKS
evaluate_scoring(cond_test, scorings)

# %%
evaluate_scoring(cond_test, scorings, n=20)

# %%
orig_items[
    orig_items.publisher == 'STONE ARCH BOOKS'
].title.tolist()

# %%
test.main_topic.str[0].unique()

# %%
orig_items['main topic'].str[0].unique()

# %%
orig_items[orig_items['main topic'].str[0] == 'L']
